# %% [markdown]
# # Code Generator
#
# The requirement: use a Frontier model to generate high performance C++ code from Python code

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder: OPTIONAL to execute C++ code or Rust code</h2>
#             <span style="color:#f71;">As an alternative, you can run it on the website given yesterday</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h1 style="color:#900;">Important Note</h1>
#             <span style="color:#900;">
#             In this lab, I use high end models GPT 5, Claude 4.5 Sonnet, Gemini 2.5 Pro, Grok 4, which are the slightly higher priced models. The costs are still low, but if you'd prefer to keep costs ultra low, please pick lower cost models like gpt-5-nano.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import io
import sys
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
import subprocess
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:6]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to client libraries

OLLAMA_BASE_URL = "http://localhost:11434/v1"

openai = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
grok_url = "https://api.x.ai/v1"
groq_url = "https://api.groq.com/openai/v1"
ollama_url = "http://localhost:11434/v1"
openrouter_url = "https://openrouter.ai/api/v1"

anthropic =  OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
gemini =  OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
grok =  OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
groq =  OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
ollama =  OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
openrouter =  OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
models = ["gpt-oss:20b", "llama3.2:latest", "deepseek-r1:8b", "mistral-nemo:12b"]

clients = {"gpt-5": openai, "claude-sonnet-4-5-20250929": anthropic, "grok-4": grok, "gemini-2.5-pro": gemini, "openai/gpt-oss-120b": groq, "qwen2.5-coder": ollama, "deepseek-coder-v2": ollama, "gpt-oss:20b": ollama, "qwen/qwen3-coder-30b-a3b-instruct": openrouter}

# Want to keep costs ultra-low? Replace this with models of your choice, using the examples from yesterday

# %%
from system_info import retrieve_system_info, rust_toolchain_info

system_info = retrieve_system_info()
rust_info = rust_toolchain_info()
rust_info
# Out:
# {'installed': False,
#  'rustc': {'path': '',
#   'version': '',
#   'host_triple': '',
#   'release': '',
#   'commit_hash': ''},
#  'cargo': {'path': '', 'version': ''},
#  'rustup': {'path': '',
#   'version': '',
#   'active_toolchain': '',
#   'default_toolchain': '',
#   'toolchains': [],
#   'targets_installed': []},
#  'rust_analyzer': {'path': ''},
#  'env': {'CARGO_HOME': '',
#   'RUSTUP_HOME': '',
#   'RUSTFLAGS': '',
#   'CARGO_BUILD_TARGET': ''},
#  'execution_examples': []}

# %%
message = f"""
I am running inside Programiz (online compiler, no sudo).

Goal:
Compile a single Rust file called main.rs and run it with the fastest possible runtime performance.
Compile time may be slow.

Requirements:
- If Rust is NOT installed, install it locally via rustup (no sudo).
- Then compile main.rs using maximum optimizations.
- Then run the produced binary.

Constraints:
- Assume generic CPU (do NOT use target-cpu=native).
- Prefer static linking if available.
- Use highest optimization level.
- Use LTO.
- Strip symbols.

If Rust is already installed, skip installation.

Then show me exactly what Python subprocess commands to use for:

compile_command  
run_command  

Format:

```python
compile_command = [...]
run_command = [...]
````

Use these flags for best runtime performance on Programiz:

rustc main.rs 
-O 
-C opt-level=3 
-C lto=fat 
-C codegen-units=1 
-C panic=abort 
-C strip=symbols 
-o main

Finally run:

./main

Return ONLY the two Python command arrays.

Do not explain anything.

"""

response = openai.chat.completions.create(model= "gpt-oss:20b", messages=[{"role": "user", "content": message}])
display(Markdown(response.choices[0].message.content))
# Out:
# ```python
# compile_command = [
#     'rustc', 'main.rs', '-O',
#     '-C', 'opt-level=3',
#     '-C', 'lto=fat',
#     '-C', 'codegen-units=1',
#     '-C', 'panic=abort',
#     '-C', 'strip=symbols',
#     '-o', 'main'
# ]
#
# run_command = [
#     './main'
# ]
# ```

# %% [markdown]
# ## For C++, overwrite this with the commands from yesterday, or for Rust, use the new commands
#
# Or just use the website like yesterday:
#
#  https://www.programiz.com/cpp-programming/online-compiler/

# %%
compile_command = [
    "/Users/ed/.cargo/bin/rustc",
    "main.rs",
    "-C", "opt-level=3",
    "-C", "target-cpu=native",
    "-C", "codegen-units=1",
    "-C", "lto=fat",
    "-C", "panic=abort",
    "-C", "strip=symbols",
    "-o", "main",
]

run_command = ["./main"]

# %% [markdown]
# ## And now, on with the main task

# %%
language = "Rust" # or "C++"
extension = "rs" if language == "Rust" else "cpp"

system_prompt = f"""
Your task is to convert Python code into high performance {language} code.
Respond only with {language} code. Do not provide any explanation other than occasional comments.
The {language} response needs to produce an identical output in the fastest possible time.
"""

def user_prompt_for(python):
    return f"""
Port this Python code to {language} with the fastest possible implementation that produces identical output in the least time.
The system information is:
{system_info}
Your response will be written to a file called main.{language} and then compiled and executed; the compilation command is:
{compile_command}
Respond only with {language} code.
Python code to port:

```python
{python}
```
"""

# %%
def messages_for(python):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(python)}
    ]

# %%
def write_output(code):
    print("Saving to file")
    with open(f"main.{extension}", "w") as f:
        f.write(code)

# %%
def port(model, python):
    client = openai
    reasoning_effort = "high" if 'gpt' in model else None
    response = client.chat.completions.create(model= "gpt-oss:20b", messages=messages_for(python), reasoning_effort=reasoning_effort)
    reply = response.choices[0].message.content
    reply = reply.replace('```cpp','').replace('```rust','').replace('```','')
    print("Reply : ",reply)
    return reply

# %%
def run_python(code):
    globals_dict = {"__builtins__": __builtins__}

    buffer = io.StringIO()
    old_stdout = sys.stdout
    sys.stdout = buffer

    try:
        exec(code, globals_dict)
        output = buffer.getvalue()
    except Exception as e:
        output = f"Error: {e}"
    finally:
        sys.stdout = old_stdout

    return output

# %%
# Use the commands from GPT 5

def compile_and_run(code):
    write_output(code)
    try:
        subprocess.run(compile_command, check=True, text=True, capture_output=True)
        run_result = subprocess.run(run_command, check=True, text=True, capture_output=True)
        return run_result.stdout
    except subprocess.CalledProcessError as e:
        return f"An error occurred:\n{e.stderr}"

# %%
python_hard = """# Be careful to support large numbers

def lcg(seed, a=1664525, c=1013904223, m=2**32):
    value = seed
    while True:
        value = (a * value + c) % m
        yield value
        
def max_subarray_sum(n, seed, min_val, max_val):
    lcg_gen = lcg(seed)
    random_numbers = [next(lcg_gen) % (max_val - min_val + 1) + min_val for _ in range(n)]
    max_sum = float('-inf')
    for i in range(n):
        current_sum = 0
        for j in range(i, n):
            current_sum += random_numbers[j]
            if current_sum > max_sum:
                max_sum = current_sum
    return max_sum

def total_max_subarray_sum(n, initial_seed, min_val, max_val):
    total_sum = 0
    lcg_gen = lcg(initial_seed)
    for _ in range(20):
        seed = next(lcg_gen)
        total_sum += max_subarray_sum(n, seed, min_val, max_val)
    return total_sum

# Parameters
n = 10000         # Number of random numbers
initial_seed = 42 # Initial seed for the LCG
min_val = -10     # Minimum value of random numbers
max_val = 10      # Maximum value of random numbers

# Timing the function
import time
start_time = time.time()
result = total_max_subarray_sum(n, initial_seed, min_val, max_val)
end_time = time.time()

print("Total Maximum Subarray Sum (20 runs):", result)
print("Execution Time: {:.6f} seconds".format(end_time - start_time))
"""

# %%
from styles import CSS

with gr.Blocks(css=CSS, theme=gr.themes.Monochrome(), title=f"Port from Python to {language}") as ui:
    with gr.Row(equal_height=True):
        with gr.Column(scale=6):
            python = gr.Code(
                label="Python (original)",
                value=python_hard,
                language="python",
                lines=26
            )
        with gr.Column(scale=6):
            cpp = gr.Code(
                label=f"{language} (generated)",
                value="",
                language="cpp",
                lines=26
            )

    with gr.Row(elem_classes=["controls"]):
        python_run = gr.Button("Run Python", elem_classes=["run-btn", "py"])
        model = gr.Dropdown(models, value=models[0], show_label=False)
        convert = gr.Button(f"Port to {language}", elem_classes=["convert-btn"])
        cpp_run = gr.Button(f"Run {language}", elem_classes=["run-btn", "cpp"])

    with gr.Row(equal_height=True):
        with gr.Column(scale=6):
            python_out = gr.TextArea(label="Python result", lines=8, elem_classes=["py-out"])
        with gr.Column(scale=6):
            cpp_out = gr.TextArea(label=f"{language} result", lines=8, elem_classes=["cpp-out"])

    convert.click(fn=port, inputs=[model, python], outputs=[cpp])
    python_run.click(fn=run_python, inputs=[python], outputs=[python_out])
    cpp_run.click(fn=compile_and_run, inputs=[cpp], outputs=[cpp_out])

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Opening in existing browser session.
# Reply :  use std::time::Instant;
#
# const N: usize = 10_000;
# const INITIAL_SEED: u32 = 42;
# const MIN_VAL: i32 = -10;
# const MAX_VAL: i32 = 10;
# const ROUNDS: usize = 20;
#
# struct Lcg {
#     state: u32,
# }
#
# impl Lcg {
#     fn new(seed: u32) -> Self {
#         Self { state: seed }
#     }
#     fn next(&mut self) -> u32 {
#         self.state = self
#             .state
#             .wrapping_mul(1664525)
#             .wrapping_add(1013904223);
#         self.state
#     }
# }
#
# fn generate_random_numbers(lcg: &mut Lcg) -> Vec<i32> {
#     let range = ((MAX_VAL - MIN_VAL + 1) as u32).wrapping_add(1);
#     (0..N)
#         .map(|_| {
#             let val = lcg.next();
#             let num = (val % range) as i32 + MIN_VAL;
#             num
#         })
#         .collect()
# }
#
# fn max_subarray_sum(nums: &[i32]) -> i64 {
#     let mut best: i64 = i64::MIN;
#     let mut current: i64 = 0;
#     for &x in nums {
#         current = std::cmp::max(current, current + x as i64);
#         best = std::cmp::max(best, current);
#     }
#     best
# }
#
# fn total_max_subarray_sum() -> i64 {
#     let mut total: i64 = 0;
#     let mut lcg = Lcg::new(INITIAL_SEED);
#     for _ in 0..ROUNDS {
#         let seed = lcg.next();
#         let mut lcg_run = Lcg::new(seed);
#         let nums = generate_random_numbers(&mut lcg_run);
#         total += max_subarray_sum(&nums);
#     }
#     total
# }
#
# fn main() {
#     let start = Instant::now();
#     let result = total_max_subarray_sum();
#     let duration = start.elapsed().as_secs_f64();
#     println!("Total Maximum Subarray Sum (20 runs): {}", result);
#     println!("Execution Time: {:.6} seconds", duration);
# }
#
# Saving to file
# Traceback (most recent call last):
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2485, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 976, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_7129/3180071184.py", line 6, in compile_and_run
#     subprocess.run(compile_command, check=True, text=True, capture_output=True)
#   File "/home/tanishq/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/tanishq/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ed/.cargo/bin/rustc'
# Reply :  use std::time::Instant;
#
# struct Lcg {
#     value: u32,
# }
#
# impl Lcg {
#     const A: u32 = 1_664_525;
#     const C: u32 = 1_013_904_223;
#
#     fn new(seed: u32) -> Self {
#         Self { value: seed }
#     }
#
#     fn next(&mut self) -> u32 {
#         self.value = self.value.wrapping_mul(Self::A).wrapping_add(Self::C);
#         self.value
#     }
# }
#
# fn max_subarray_sum(n: usize, seed: u32, min_val: i32, max_val: i32) -> i32 {
#     let mut lcg = Lcg::new(seed);
#     let range = (max_val - min_val + 1) as u32;
#     let mut arr = Vec::with_capacity(n);
#     for _ in 0..n {
#         let val = (lcg.next() % range) as i32 + min_val;
#         arr.push(val);
#     }
#
#     let mut max_sum = i32::MIN;
#     for i in 0..n {
#         let mut current_sum = 0i32;
#         for j in i..n {
#             current_sum += arr[j];
#             if current_sum > max_sum {
#                 max_sum = current_sum;
#             }
#         }
#     }
#     max_sum
# }
#
# fn total_max_subarray_sum(n: usize, initial_seed: u32, min_val: i32, max_val: i32) -> i64 {
#     let mut lcg = Lcg::new(initial_seed);
#     let mut total_sum: i64 = 0;
#     for _ in 0..20 {
#         let seed = lcg.next();
#         let max_sum = max_subarray_sum(n, seed, min_val, max_val);
#         total_sum += max_sum as i64;
#     }
#     total_sum
# }
#
# fn main() {
#     const N: usize = 10_000;
#     const INITIAL_SEED: u32 = 42;
#     const MIN_VAL: i32 = -10;
#     const MAX_VAL: i32 = 10;
#
#     let start = Instant::now();
#     let result = total_max_subarray_sum(N, INITIAL_SEED, MIN_VAL, MAX_VAL);
#     let duration = start.elapsed();
#     let secs = duration.as_secs_f64();
#
#     println!("Total Maximum Subarray Sum (20 runs): {}", result);
#     println!("Execution Time: {:.6} seconds", secs);
# }
#
# Reply :
# // main.rs
#
# use std::time::Instant;
#
# // Linear Congruential Generator constants
# const A: u32 = 1664525;
# const C: u32 = 1013904223;
# const MASK: u64 = 0xFFFF_FFFF;
#
# // Advance the LCG and return the next value
# #[inline]
# fn next_lcg(val: &mut u32) -> u32 {
#     let next = ((*val as u64) * (A as u64) + (C as u64)) & MASK;
#     *val = next as u32;
#     *val
# }
#
# // Compute maximum subarray sum using Kadane's algorithm
# fn max_subarray_sum(arr: &[i32]) -> i64 {
#     let mut max_ending = 0_i64;
#     let mut max_sofar = i64::MIN;
#     for &x in arr {
#         let val = x as i64;
#         max_ending = std::cmp::max(val, max_ending + val);
#         max_sofar = std::cmp::max(max_sofar, max_ending);
#     }
#     max_sofar
# }
#
# // Generate an array of length n using the LCG seeded with `seed`
# fn generate_array(seed: u32, n: usize, min_val: i32, max_val: i32) -> Vec<i32> {
#     let mut lcg_val = seed;
#     let span = (max_val - min_val + 1) as u32;
#     let mut arr = Vec::with_capacity(n);
#     for _ in 0..n {
#         let rnd = next_lcg(&mut lcg_val);
#         let val = (rnd % span) as i32 + min_val;
#         arr.push(val);
#     }
#     arr
# }
#
# // Compute total maximum subarray sum over 20 runs
# fn total_max_subarray_sum(n: usize, initial_seed: u32, min_val: i32, max_val: i32) -> i64 {
#     let mut total = 0_i64;
#     let mut lcg_val = initial_seed;
#     for _ in 0..20 {
#         let seed = next_lcg(&mut lcg_val);
#         let arr = generate_array(seed, n, min_val, max_val);
#         total += max_subarray_sum(&arr);
#     }
#     total
# }
#
# fn main() {
#     // Parameters
#     let n: usize = 10_000;
#     let initial_seed: u32 = 42;
#     let min_val: i32 = -10;
#     let max_val: i32 = 10;
#
#     let start = Instant::now();
#     let result = total_max_subarray_sum(n, initial_seed, min_val, max_val);
#     let duration = start.elapsed();
#
#     println!("Total Maximum Subarray Sum (20 runs): {}", result);
#     println!("Execution Time: {:.6} seconds", duration.as_secs_f64());
# }
#
# Reply :
# // main.rs
# use std::time::Instant;
#
# // Linear Congruential Generator
# struct LCG {
#     value: u64,
#     a: u64,
#     c: u64,
#     m: u64,
# }
#
# impl LCG {
#     fn new(seed: u64) -> Self {
#         LCG {
#             value: seed,
#             a: 1664525,
#             c: 1013904223,
#             m: 1u64 << 32,
#         }
#     }
#
#     fn next(&mut self) -> u32 {
#         self.value = (self.a * self.value + self.c) % self.m;
#         self.value as u32
#     }
# }
#
# // Computes maximum subarray sum using O(n²) algorithm
# fn max_subarray_sum(n: usize, seed: u32, min_val: i64, max_val: i64) -> i64 {
#     let mut rng = LCG::new(seed as u64);
#     let range = (max_val - min_val + 1) as u32;
#     let mut nums = Vec::with_capacity(n);
#     for _ in 0..n {
#         let val = rng.next() % range;
#         nums.push(val as i64 + min_val);
#     }
#
#     let mut max_sum = i64::MIN;
#     for i in 0..n {
#         let mut curr = 0i64;
#         for j in i..n {
#             curr += nums[j];
#             if curr > max_sum {
#                 max_sum = curr;
#             }
#         }
#     }
#     max_sum
# }
#
# // Computes total maximum subarray sum over 20 seeds
# fn total_max_subarray_sum(n: usize, initial_seed: u32, min_val: i64, max_val: i64) -> i64 {
#     let mut total = 0i64;
#     let mut rng = LCG::new(initial_seed as u64);
#     for _ in 0..20 {
#         let seed = rng.next();
#         total += max_subarray_sum(n, seed, min_val, max_val);
#     }
#     total
# }
#
# fn main() {
#     // Parameters
#     let n: usize = 10_000;
#     let initial_seed: u32 = 42;
#     let min_val: i64 = -10;
#     let max_val: i64 = 10;
#
#     let start = Instant::now();
#     let result = total_max_subarray_sum(n, initial_seed, min_val, max_val);
#     let duration = start.elapsed();
#
#     println!("Total Maximum Subarray Sum (20 runs): {}", result);
#     println!(
#         "Execution Time: {:.6} seconds",
#         duration.as_secs_f64()
#     );
# }
#
# Reply :
# use std::time::Instant;
#
# const N: usize = 10_000;
# const INITIAL_SEED: u32 = 42;
# const MIN_VAL: i32 = -10;
# const MAX_VAL: i32 = 10;
#
# /// LCG parameters (32‑bit)
# const A: u32 = 1_664_525;
# const C: u32 = 1_013_904_223;
#
# #[inline(always)]
# fn lcg_next(seed: &mut u32) -> u32 {
#     *seed = seed.wrapping_mul(A).wrapping_add(C);
#     *seed
# }
#
# #[inline(always)]
# fn max_subarray_sum(n: usize, seed: u32, min_val: i32, max_val: i32) -> i64 {
#     let mut s = seed;
#     let mut best: i64 = i64::MIN;
#     let mut cur: i64 = 0;
#     let range = (max_val - min_val + 1) as u32;
#
#     for _ in 0..n {
#         s = lcg_next(&mut s);
#         let val = (s % range) as i32 + min_val;
#         cur += val as i64;
#         if cur > best {
#             best = cur;
#         }
#         if cur < 0 {
#             cur = 0;
#         }
#     }
#     best
# }
#
# fn main() {
#     let start = Instant::now();
#
#     let mut total: i64 = 0;
#     let mut seed = INITIAL_SEED;
#
#     for _ in 0..20 {
#         let next_seed = lcg_next(&mut seed);
#         total += max_subarray_sum(N, next_seed, MIN_VAL, MAX_VAL);
#     }
#
#     let duration = start.elapsed();
#
#     println!("Total Maximum Subarray Sum (20 runs): {}", total);
#     println!("Execution Time: {:.6} seconds", duration.as_secs_f64());
# }

# %% [markdown]
# ## RESULTS!
#
# Qwen 2.5 Coder: FAIL
# Gemini 2.5 Pro: FAIL
# DeepSeek Coder v2: FAIL
# Qwen3 Coder 30B: FAIL
# Claude Sonnet 4.5: FAIL
# GPT-5: FAIL
#
# 3rd place: GPT-oss-20B: 0.000341
# 2nd place: Grok 4: 0.000317
# **1st place: OpenAI GPT-OSS 120B: 0.000304**
#
# mistral-nemo = {Total Maximum Subarray Sum (20 runs): 10980; Execution Time: 0.002698 seconds}
# Chatgpt = { Total Maximum Subarray Sum (20 runs): 10980, Execution Time: 0.002628 seconds}
# gptoss:20B = { Total Maximum Subarray Sum (20 runs): 10980, Execution Time: 0.002376 seconds}
# llma = {Total Maximum Subarray Sum (20 runs): 594870, Execution Time: 0.006921 seconds}
# deepseek = {Total Maximum Subarray Sum (20 runs): 10980, Execution Time: 19.241426 seconds}

# %%
print(f"In Ed's experimenet, the GPT-OSS 120B model outcome is {33.755209/0.000304:,.0f} times faster than the Python code.")
# Out:
# In Ed's experimenet, the GPT-OSS 120B model outcome is 111,037 times faster than the Python code.
# Traceback (most recent call last):
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2485, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 976, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tanishq/Code/llm_engineering/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_7129/4052890587.py", line 2, in port
#     client = clients[model]
#              ^^^^^^^
# NameError: name 'clients' is not defined

# %%
# Be careful to support large numbers

def lcg(seed, a=1664525, c=1013904223, m=2**32):
    value = seed
    while True:
        value = (a * value + c) % m
        yield value
        
def max_subarray_sum(n, seed, min_val, max_val):
    lcg_gen = lcg(seed)
    random_numbers = [next(lcg_gen) % (max_val - min_val + 1) + min_val for _ in range(n)]
    max_sum = float('-inf')
    for i in range(n):
        current_sum = 0
        for j in range(i, n):
            current_sum += random_numbers[j]
            if current_sum > max_sum:
                max_sum = current_sum
    return max_sum

def total_max_subarray_sum(n, initial_seed, min_val, max_val):
    total_sum = 0
    lcg_gen = lcg(initial_seed)
    for _ in range(20):
        seed = next(lcg_gen)
        total_sum += max_subarray_sum(n, seed, min_val, max_val)
    return total_sum

# Parameters
n = 10000         # Number of random numbers
initial_seed = 42 # Initial seed for the LCG
min_val = -10     # Minimum value of random numbers
max_val = 10      # Maximum value of random numbers

# Timing the function
import time
start_time = time.time()
result = total_max_subarray_sum(n, initial_seed, min_val, max_val)
end_time = time.time()

print("Total Maximum Subarray Sum (20 runs):", result)
print("Execution Time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Total Maximum Subarray Sum (20 runs): 10980
# Execution Time: 45.157606 seconds

# %%
import time

def calculate(iterations, param1, param2):
    result = 1.0
    for i in range(1, iterations+1):
        j = i * param1 - param2
        result -= (1/j)
        j = i * param1 + param2
        result += (1/j)
    return result

start_time = time.time()
result = calculate(200_000_000, 4, 1) * 4
end_time = time.time()

print(f"Result: {result:.12f}")
print(f"Execution Time: {(end_time - start_time):.6f} seconds")
# Out:
# Result: 3.141592656089
# Execution Time: 26.116931 seconds

# %%
# Out:
#   Cell In[58], line 1
#     Total Maximum Subarray Sum (20 runs): 10980
#           ^
# SyntaxError: invalid syntax
