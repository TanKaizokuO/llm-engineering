# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 evaluate_retrieval(example)
#
# File ~/Code/llm_engineering/week5/evaluation/eval.py:93, in evaluate_retrieval(test, k)
#      82 """
#      83 Evaluate retrieval performance for a test question.
#      84
#    (...)     90     RetrievalEval object with MRR, nDCG, and keyword coverage metrics
#      91 """
#      92 # Retrieve documents using shared answer module
# ---> 93 retrieved_docs = fetch_context(test.question)
#      95 # Calculate MRR (average across all keywords)
#      96 mrr_scores = [calculate_mrr(keyword, retrieved_docs) for keyword in test.keywords]
#
# File ~/Code/llm_engineering/week5/implementation/answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:216, in BaseRetriever.invoke(self, input, config, **kwargs)
#     214 kwargs_ = kwargs if self._expects_other_args else {}
#     215 if self._new_arg_supported:
# --> 216     result = self._get_relevant_documents(
#     217         input, run_manager=run_manager, **kwargs_
#     218     )
#     219 else:
#     220     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1033, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1031 kwargs_ = self.search_kwargs | kwargs
#    1032 if self.search_type == "similarity":
# -> 1033     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1034 elif self.search_type == "similarity_score_threshold":
#    1035     docs_and_similarities = (
#    1036         self.vectorstore.similarity_search_with_relevance_scores(
#    1037             query, **kwargs_
#    1038         )
#    1039     )
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:695, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     677 def similarity_search(
#     678     self,
#     679     query: str,
#    (...)    682     **kwargs: Any,
#     683 ) -> list[Document]:
#     684     """Run similarity search with Chroma.
#     685
#     686     Args:
#    (...)    693         List of documents most similar to the query text.
#     694     """
# --> 695     docs_and_scores = self.similarity_search_with_score(
#     696         query,
#     697         k,
#     698         filter=filter,
#     699         **kwargs,
#     700     )
#     701     return [doc for doc, _ in docs_and_scores]
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:795, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     787     results = self.__query_collection(
#     788         query_texts=[query],
#     789         n_results=k,
#    (...)    792         **kwargs,
#     793     )
#     794 else:
# --> 795     query_embedding = self._embedding_function.embed_query(query)
#     796     results = self.__query_collection(
#     797         query_embeddings=[query_embedding],
#     798         n_results=k,
#    (...)    801         **kwargs,
#     802     )
#     804 return _results_to_docs_and_scores(results)
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:674, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     664 """Call out to OpenAI's embedding endpoint for embedding query text.
#     665
#     666 Args:
#    (...)    671     Embedding for the text.
#     672 """
#     673 self._ensure_sync_client_available()
# --> 674 return self.embed_documents([text], **kwargs)[0]
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:625, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     622 # NOTE: to keep things simple, we assume the list may contain texts longer
#     623 #       than the maximum context and use length-safe embedding function.
#     624 engine = cast(str, self.deployment)
# --> 625 return self._get_len_safe_embeddings(
#     626     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     627 )
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:514, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     512 batched_embeddings: list[list[float]] = []
#     513 for i in _iter:
# --> 514     response = self.client.create(
#     515         input=tokens[i : i + _chunk_size], **client_kwargs
#     516     )
#     517     if not isinstance(response, dict):
#     518         response = response.model_dump()
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/Code/llm_engineering/week5/evaluation/eval.py:128, in evaluate_answer(test)
#     118 """
#     119 Evaluate answer quality using LLM-as-a-judge (async).
#     120
#    (...)    125     Tuple of (AnswerEval object, generated_answer string, retrieved_docs list)
#     126 """
#     127 # Get RAG response using shared answer module
# --> 128 generated_answer, retrieved_docs = answer_question(test.question)
#     130 # LLM judge prompt
#     131 judge_messages = [
#     132     {
#     133         "role": "system",
#    (...)    153     },
#     154 ]
#
# File ~/Code/llm_engineering/week5/implementation/answer.py:54, in answer_question(question, history)
#      50 """
#      51 Answer the given question with RAG; return the answer and the context documents.
#      52 """
#      53 combined = combined_question(question, history)
# ---> 54 docs = fetch_context(combined)
#      55 context = "\n\n".join(doc.page_content for doc in docs)
#      56 system_prompt = SYSTEM_PROMPT.format(context=context)
#
# File ~/Code/llm_engineering/week5/implementation/answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:216, in BaseRetriever.invoke(self, input, config, **kwargs)
#     214 kwargs_ = kwargs if self._expects_other_args else {}
#     215 if self._new_arg_supported:
# --> 216     result = self._get_relevant_documents(
#     217         input, run_manager=run_manager, **kwargs_
#     218     )
#     219 else:
#     220     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1033, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1031 kwargs_ = self.search_kwargs | kwargs
#    1032 if self.search_type == "similarity":
# -> 1033     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1034 elif self.search_type == "similarity_score_threshold":
#    1035     docs_and_similarities = (
#    1036         self.vectorstore.similarity_search_with_relevance_scores(
#    1037             query, **kwargs_
#    1038         )
#    1039     )
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:695, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     677 def similarity_search(
#     678     self,
#     679     query: str,
#    (...)    682     **kwargs: Any,
#     683 ) -> list[Document]:
#     684     """Run similarity search with Chroma.
#     685
#     686     Args:
#    (...)    693         List of documents most similar to the query text.
#     694     """
# --> 695     docs_and_scores = self.similarity_search_with_score(
#     696         query,
#     697         k,
#     698         filter=filter,
#     699         **kwargs,
#     700     )
#     701     return [doc for doc, _ in docs_and_scores]
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:795, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     787     results = self.__query_collection(
#     788         query_texts=[query],
#     789         n_results=k,
#    (...)    792         **kwargs,
#     793     )
#     794 else:
# --> 795     query_embedding = self._embedding_function.embed_query(query)
#     796     results = self.__query_collection(
#     797         query_embeddings=[query_embedding],
#     798         n_results=k,
#    (...)    801         **kwargs,
#     802     )
#     804 return _results_to_docs_and_scores(results)
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:674, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     664 """Call out to OpenAI's embedding endpoint for embedding query text.
#     665
#     666 Args:
#    (...)    671     Embedding for the text.
#     672 """
#     673 self._ensure_sync_client_available()
# --> 674 return self.embed_documents([text], **kwargs)[0]
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:625, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     622 # NOTE: to keep things simple, we assume the list may contain texts longer
#     623 #       than the maximum context and use length-safe embedding function.
#     624 engine = cast(str, self.deployment)
# --> 625 return self._get_len_safe_embeddings(
#     626     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     627 )
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:514, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     512 batched_embeddings: list[list[float]] = []
#     513 for i in _iter:
# --> 514     response = self.client.create(
#     515         input=tokens[i : i + _chunk_size], **client_kwargs
#     516     )
#     517     if not isinstance(response, dict):
#     518         response = response.model_dump()
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/openai/resources/embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Code/llm_engineering/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(eval.feedback)
#       2 print(eval.accuracy)
#       3 print(eval.completeness)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'feedback'
